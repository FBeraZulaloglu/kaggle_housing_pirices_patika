# %%
from sklearn.ensemble import RandomForestRegressor
from IPython.display import display
from sklearn import metrics

# %%
import pandas as pd
import numpy as np

# %%
import math

# %%
Path = "data/"

# %%
df = pd.read_csv(f"{Path}train.csv",low_memory=False)

# %%
df.head(100)
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60         4         65.0     8450   Pave   NaN      Reg
# 1     2          20         4         80.0     9600   Pave   NaN      Reg
# 2     3          60         4         68.0    11250   Pave   NaN      IR1
# 3     4          70         4         60.0     9550   Pave   NaN      IR1
# 4     5          60         4         84.0    14260   Pave   NaN      IR1
# ..  ...         ...       ...          ...      ...    ...   ...      ...
# 95   96          60         4          NaN     9765   Pave   NaN      IR2
# 96   97          20         4         78.0    10264   Pave   NaN      IR1
# 97   98          20         4         73.0    10921   Pave   NaN      Reg
# 98   99          30         4         85.0    10625   Pave   NaN      Reg
# 99  100          20         4         77.0     9320   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 2          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 3          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 4          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ..         ...       ...  ...      ...    ...   ...         ...     ...
# 95         Lvl    AllPub  ...        0    NaN   NaN        Shed     480
# 96         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 97         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 98         Lvl    AllPub  ...        0    NaN   NaN        Shed     400
# 99         Lvl    AllPub  ...        0    NaN   NaN        Shed     400
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       2   2008        WD         Normal  12.247694
# 1       5   2007        WD         Normal  12.109011
# 2       9   2008        WD         Normal  12.317167
# 3       2   2006        WD        Abnorml  11.849398
# 4      12   2008        WD         Normal  12.429216
# ..    ...    ...       ...            ...        ...
# 95      4   2009        WD         Normal  12.128111
# 96      8   2006        WD         Normal  12.273731
# 97      5   2007        WD         Normal  11.458997
# 98      5   2010       COD        Abnorml  11.326596
# 99      1   2010        WD         Normal  11.767180
#
# [100 rows x 81 columns]

# %% [markdown]
# ## RMSLE

# %%
df['SalePrice'] = np.log(df.SalePrice)

# %% [markdown]
# ## Categorical Transformation

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
for n,c in df[199:200].items():
    print(n) # name of column
    print(c) # index values
    print("----------------------------")
# Out:
# Id
# 199    200
# Name: Id, dtype: int64
# ----------------------------
# MSSubClass
# 199    20
# Name: MSSubClass, dtype: int64
# ----------------------------
# MSZoning
# 199    RL
# Name: MSZoning, dtype: category
# Categories (5, object): ['C (all)' < 'FV' < 'RH' < 'RL' < 'RM']
# ----------------------------
# LotFrontage
# 199    76.0
# Name: LotFrontage, dtype: float64
# ----------------------------
# LotArea
# 199    9591
# Name: LotArea, dtype: int64
# ----------------------------
# Street
# 199    Pave
# Name: Street, dtype: category
# Categories (2, object): ['Grvl' < 'Pave']
# ----------------------------
# Alley
# 199    NaN
# Name: Alley, dtype: category
# Categories (2, object): ['Grvl' < 'Pave']
# ----------------------------
# LotShape
# 199    Reg
# Name: LotShape, dtype: category
# Categories (4, object): ['IR1' < 'IR2' < 'IR3' < 'Reg']
# ----------------------------
# LandContour
# 199    Lvl
# Name: LandContour, dtype: category
# Categories (4, object): ['Bnk' < 'HLS' < 'Low' < 'Lvl']
# ----------------------------
# Utilities
# 199    AllPub
# Name: Utilities, dtype: category
# Categories (2, object): ['AllPub' < 'NoSeWa']
# ----------------------------
# LotConfig
# 199    Inside
# Name: LotConfig, dtype: category
# Categories (5, object): ['Corner' < 'CulDSac' < 'FR2' < 'FR3' < 'Inside']
# ----------------------------
# LandSlope
# 199    Gtl
# Name: LandSlope, dtype: category
# Categories (3, object): ['Gtl' < 'Mod' < 'Sev']
# ----------------------------
# Neighborhood
# 199    NridgHt
# Name: Neighborhood, dtype: category
# Categories (25, object): ['Blmngtn' < 'Blueste' < 'BrDale' < 'BrkSide' ... 'Somerst' < 'StoneBr' < 'Timber' < 'Veenker']
# ----------------------------
# Condition1
# 199    Norm
# Name: Condition1, dtype: category
# Categories (9, object): ['Artery' < 'Feedr' < 'Norm' < 'PosA' ... 'RRAe' < 'RRAn' < 'RRNe' < 'RRNn']
# ----------------------------
# Condition2
# 199    Norm
# Name: Condition2, dtype: category
# Categories (8, object): ['Artery' < 'Feedr' < 'Norm' < 'PosA' < 'PosN' < 'RRAe' < 'RRAn' < 'RRNn']
# ----------------------------
# BldgType
# 199    1Fam
# Name: BldgType, dtype: category
# Categories (5, object): ['1Fam' < '2fmCon' < 'Duplex' < 'Twnhs' < 'TwnhsE']
# ----------------------------
# HouseStyle
# 199    1Story
# Name: HouseStyle, dtype: category
# Categories (8, object): ['1.5Fin' < '1.5Unf' < '1Story' < '2.5Fin' < '2.5Unf' < '2Story' < 'SFoyer' < 'SLvl']
# ----------------------------
# OverallQual
# 199    8
# Name: OverallQual, dtype: int64
# ----------------------------
# OverallCond
# 199    5
# Name: OverallCond, dtype: int64
# ----------------------------
# YearBuilt
# 199    2004
# Name: YearBuilt, dtype: int64
# ----------------------------
# YearRemodAdd
# 199    2005
# Name: YearRemodAdd, dtype: int64
# ----------------------------
# RoofStyle
# 199    Hip
# Name: RoofStyle, dtype: category
# Categories (6, object): ['Flat' < 'Gable' < 'Gambrel' < 'Hip' < 'Mansard' < 'Shed']
# ----------------------------
# RoofMatl
# 199    CompShg
# Name: RoofMatl, dtype: category
# Categories (8, object): ['ClyTile' < 'CompShg' < 'Membran' < 'Metal' < 'Roll' < 'Tar&Grv' < 'WdShake' < 'WdShngl']
# ----------------------------
# Exterior1st
# 199    VinylSd
# Name: Exterior1st, dtype: category
# Categories (15, object): ['AsbShng' < 'AsphShn' < 'BrkComm' < 'BrkFace' ... 'Stucco' < 'VinylSd' < 'Wd Sdng' < 'WdShing']
# ----------------------------
# Exterior2nd
# 199    VinylSd
# Name: Exterior2nd, dtype: category
# Categories (16, object): ['AsbShng' < 'AsphShn' < 'Brk Cmn' < 'BrkFace' ... 'Stucco' < 'VinylSd' < 'Wd Sdng' < 'Wd Shng']
# ----------------------------
# MasVnrType
# 199    BrkFace
# Name: MasVnrType, dtype: category
# Categories (4, object): ['BrkCmn' < 'BrkFace' < 'None' < 'Stone']
# ----------------------------
# MasVnrArea
# 199    262.0
# Name: MasVnrArea, dtype: float64
# ----------------------------
# ExterQual
# 199    Gd
# Name: ExterQual, dtype: category
# Categories (4, object): ['Ex' < 'Fa' < 'Gd' < 'TA']
# ----------------------------
# ExterCond
# 199    TA
# Name: ExterCond, dtype: category
# Categories (5, object): ['Ex' < 'Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# Foundation
# 199    PConc
# Name: Foundation, dtype: category
# Categories (6, object): ['BrkTil' < 'CBlock' < 'PConc' < 'Slab' < 'Stone' < 'Wood']
# ----------------------------
# BsmtQual
# 199    Ex
# Name: BsmtQual, dtype: category
# Categories (4, object): ['Ex' < 'Fa' < 'Gd' < 'TA']
# ----------------------------
# BsmtCond
# 199    TA
# Name: BsmtCond, dtype: category
# Categories (4, object): ['Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# BsmtExposure
# 199    Av
# Name: BsmtExposure, dtype: category
# Categories (4, object): ['Av' < 'Gd' < 'Mn' < 'No']
# ----------------------------
# BsmtFinType1
# 199    GLQ
# Name: BsmtFinType1, dtype: category
# Categories (6, object): ['ALQ' < 'BLQ' < 'GLQ' < 'LwQ' < 'Rec' < 'Unf']
# ----------------------------
# BsmtFinSF1
# 199    1088
# Name: BsmtFinSF1, dtype: int64
# ----------------------------
# BsmtFinType2
# 199    Unf
# Name: BsmtFinType2, dtype: category
# Categories (6, object): ['ALQ' < 'BLQ' < 'GLQ' < 'LwQ' < 'Rec' < 'Unf']
# ----------------------------
# BsmtFinSF2
# 199    0
# Name: BsmtFinSF2, dtype: int64
# ----------------------------
# BsmtUnfSF
# 199    625
# Name: BsmtUnfSF, dtype: int64
# ----------------------------
# TotalBsmtSF
# 199    1713
# Name: TotalBsmtSF, dtype: int64
# ----------------------------
# Heating
# 199    GasA
# Name: Heating, dtype: category
# Categories (6, object): ['Floor' < 'GasA' < 'GasW' < 'Grav' < 'OthW' < 'Wall']
# ----------------------------
# HeatingQC
# 199    Ex
# Name: HeatingQC, dtype: category
# Categories (5, object): ['Ex' < 'Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# CentralAir
# 199    Y
# Name: CentralAir, dtype: category
# Categories (2, object): ['N' < 'Y']
# ----------------------------
# Electrical
# 199    SBrkr
# Name: Electrical, dtype: category
# Categories (5, object): ['FuseA' < 'FuseF' < 'FuseP' < 'Mix' < 'SBrkr']
# ----------------------------
# 1stFlrSF
# 199    1713
# Name: 1stFlrSF, dtype: int64
# ----------------------------
# 2ndFlrSF
# 199    0
# Name: 2ndFlrSF, dtype: int64
# ----------------------------
# LowQualFinSF
# 199    0
# Name: LowQualFinSF, dtype: int64
# ----------------------------
# GrLivArea
# 199    1713
# Name: GrLivArea, dtype: int64
# ----------------------------
# BsmtFullBath
# 199    1
# Name: BsmtFullBath, dtype: int64
# ----------------------------
# BsmtHalfBath
# 199    0
# Name: BsmtHalfBath, dtype: int64
# ----------------------------
# FullBath
# 199    2
# Name: FullBath, dtype: int64
# ----------------------------
# HalfBath
# 199    0
# Name: HalfBath, dtype: int64
# ----------------------------
# BedroomAbvGr
# 199    3
# Name: BedroomAbvGr, dtype: int64
# ----------------------------
# KitchenAbvGr
# 199    1
# Name: KitchenAbvGr, dtype: int64
# ----------------------------
# KitchenQual
# 199    Ex
# Name: KitchenQual, dtype: category
# Categories (4, object): ['Ex' < 'Fa' < 'Gd' < 'TA']
# ----------------------------
# TotRmsAbvGrd
# 199    7
# Name: TotRmsAbvGrd, dtype: int64
# ----------------------------
# Functional
# 199    Typ
# Name: Functional, dtype: category
# Categories (7, object): ['Maj1' < 'Maj2' < 'Min1' < 'Min2' < 'Mod' < 'Sev' < 'Typ']
# ----------------------------
# Fireplaces
# 199    1
# Name: Fireplaces, dtype: int64
# ----------------------------
# FireplaceQu
# 199    Gd
# Name: FireplaceQu, dtype: category
# Categories (5, object): ['Ex' < 'Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# GarageType
# 199    Attchd
# Name: GarageType, dtype: category
# Categories (6, object): ['2Types' < 'Attchd' < 'Basment' < 'BuiltIn' < 'CarPort' < 'Detchd']
# ----------------------------
# GarageYrBlt
# 199    2004.0
# Name: GarageYrBlt, dtype: float64
# ----------------------------
# GarageFinish
# 199    Fin
# Name: GarageFinish, dtype: category
# Categories (3, object): ['Fin' < 'RFn' < 'Unf']
# ----------------------------
# GarageCars
# 199    3
# Name: GarageCars, dtype: int64
# ----------------------------
# GarageArea
# 199    856
# Name: GarageArea, dtype: int64
# ----------------------------
# GarageQual
# 199    TA
# Name: GarageQual, dtype: category
# Categories (5, object): ['Ex' < 'Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# GarageCond
# 199    TA
# Name: GarageCond, dtype: category
# Categories (5, object): ['Ex' < 'Fa' < 'Gd' < 'Po' < 'TA']
# ----------------------------
# PavedDrive
# 199    Y
# Name: PavedDrive, dtype: category
# Categories (3, object): ['N' < 'P' < 'Y']
# ----------------------------
# WoodDeckSF
# 199    0
# Name: WoodDeckSF, dtype: int64
# ----------------------------
# OpenPorchSF
# 199    26
# Name: OpenPorchSF, dtype: int64
# ----------------------------
# EnclosedPorch
# 199    0
# Name: EnclosedPorch, dtype: int64
# ----------------------------
# 3SsnPorch
# 199    0
# Name: 3SsnPorch, dtype: int64
# ----------------------------
# ScreenPorch
# 199    170
# Name: ScreenPorch, dtype: int64
# ----------------------------
# PoolArea
# 199    0
# Name: PoolArea, dtype: int64
# ----------------------------
# PoolQC
# 199    NaN
# Name: PoolQC, dtype: category
# Categories (3, object): ['Ex' < 'Fa' < 'Gd']
# ----------------------------
# Fence
# 199    NaN
# Name: Fence, dtype: category
# Categories (4, object): ['GdPrv' < 'GdWo' < 'MnPrv' < 'MnWw']
# ----------------------------
# MiscFeature
# 199    NaN
# Name: MiscFeature, dtype: category
# Categories (4, object): ['Gar2' < 'Othr' < 'Shed' < 'TenC']
# ----------------------------
# MiscVal
# 199    0
# Name: MiscVal, dtype: int64
# ----------------------------
# MoSold
# 199    1
# Name: MoSold, dtype: int64
# ----------------------------
# YrSold
# 199    2009
# Name: YrSold, dtype: int64
# ----------------------------
# SaleType
# 199    WD
# Name: SaleType, dtype: category
# Categories (9, object): ['COD' < 'CWD' < 'Con' < 'ConLD' ... 'ConLw' < 'New' < 'Oth' < 'WD']
# ----------------------------
# SaleCondition
# 199    Normal
# Name: SaleCondition, dtype: category
# Categories (6, object): ['Abnorml' < 'AdjLand' < 'Alloca' < 'Family' < 'Normal' < 'Partial']
# ----------------------------
# SalePrice
# 199    12.524163
# Name: SalePrice, dtype: float64
# ----------------------------

# %%
def train_categorize(df):
    for n,c in df.items():
        if pd.api.types.is_string_dtype(c): # if value is a string in train data
            df[n] = c.astype("category").cat.as_ordered() # categorize the value

# %% [markdown]
# When I apply categorization for train set then I have to use the same categorization for validation and test sets.
# Because of that I wil write a second method that uses train's categorization for validation and test sets.

# %%
def apply_categorize(df,train):
    for n,c in df.items():
        if train[n].dtype == "category":
            df[n] = pd.Categorical(c,categories= train[n].cat.categories,ordered=True)

# %%
train_categorize(df)

# %%
df['MSZoning']
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: category
# Categories (5, object): ['C (all)' < 'FV' < 'RH' < 'RL' < 'RM']

# %%
df['MSZoning'].cat.categories
# Out:
# Index(['C (all)', 'FV', 'RH', 'RL', 'RM'], dtype='object')

# %% [markdown]
# When we categorize the variables in the front we do not see any differences but in the backend we can see that it is mapping and it will store the variables as numerical values by typing ".cat.codes" Also missing values are -1 for pandas. To change the column in the front too we are going to write a numericalize method

# %%
def numericalize(df,col,name):
    if not pd.api.types.is_numeric_dtype(col):
        df[name] = col.cat.codes + 1

# %%
numericalize(df,df['MSZoning'],"MSZoning")
df['MSZoning']
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 1455    4
# 1456    4
# 1457    4
# 1458    4
# 1459    4
# Name: MSZoning, Length: 1460, dtype: int8

# %%
def fix_missing(df,col,name):
    if pd.api.types.is_numeric_dtype(col):
        if pd.isnull(col).sum:
            df[name+"na"] = pd.isnull(col)
        df[name] = col.fillna(df[name].median())

# %%
def proc_df(df):
    
    df = df.copy()
    for n, c in df.items():
        fix_missing(df,c,n)
        numericalize(df,c,n)
    
    return df

# %%
df_processed,y = proc_df(df,"SalePrice")

# %%
df_processed.head(100)
# Out:
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
#         ...
# 95    12.128111
# 96    12.273731
# 97    11.458997
# 98    11.326596
# 99    11.767180
# Name: SalePrice, Length: 100, dtype: float64

# %% [markdown]
# ## TRAIN VALIDATION SPLIT

# %%
df_processed["YrSold"]
# Out:
# 0       2008
# 1       2007
# 2       2008
# 3       2006
# 4       2008
#         ...
# 1455    2007
# 1456    2010
# 1457    2010
# 1458    2010
# 1459    2008
# Name: YrSold, Length: 1460, dtype: int64

# %%
df_sorted = df_processed.sort_values(by='YrSold')
df_sorted["YrSold"].tail(100)
# Out:
# 142     2010
# 1358    2010
# 234     2010
# 233     2010
# 230     2010
#         ...
# 353     2010
# 1322    2010
# 162     2010
# 158     2010
# 1284    2010
# Name: YrSold, Length: 100, dtype: int64

# %%
def split_train_val(df,n):
    # df = dataset of the validation and train
    # the number of the train dataset
    return df[:n].copy(),df[n:].copy() # We are giving the current data to the validation

# %%
len(df_sorted)
# Out:
# 1460

# %%
n_valid = 360
n_train = len(df_sorted) - n_valid
train,valid = split_train_val(df_sorted,n_train)

# %%
y_train = train["SalePrice"].values
train.drop("SalePrice", axis=1, inplace=True)
x_train = train

# %%
y_valid = valid["SalePrice"].values
valid.drop("SalePrice", axis=1, inplace=True)
x_valid = valid

# %%
print(f"x train length: {len(x_train)}")
print(f"y train length: {len(y_train)}")
print(f"x valid length: {len(x_valid)}")
print(f"y valid length: {len(y_valid)}")
# Out:
# x train length: 1100
# y train length: 1100
# x valid length: 360
# y valid length: 360

# %% [markdown]
# ## Train Random Forest

# %%
m = RandomForestRegressor(n_estimators=1, bootstrap=False,n_jobs=-1)
m.fit(x_train,y)
# Out:
# RandomForestRegressor(bootstrap=False, n_estimators=1, n_jobs=-1)

# %%
def rmse(x,y):
    return math.sqrt(((x-y)**2).mean())

# %%
def print_score(m):
    print("RMSE ERRORS")
    print(f"Train set: {rmse(m.predict(x_train,y_train))}")
    print(f"Validation set: {rmse(m.predict(x_train,y_train))}")
    print("R^2 ERRORS")
    print(f"Train set: {m.score(x_train,y_train)}")
    print(f"Validation set: {m.score(x_train,y_train)}")
